# %% [markdown]
# # Create Annotations
#
# This program creates an xml file and copy of an image for training machine learning models.
# This program opens a directory and for each image in the folder:
# - displays it
# - Allows the user to drag the mouse to create rectangles of the areas in the image that contain items to train the model on.
# - press w to write the xml file and image to go to the next image
# - press + to go to the next image if there is nothing to train in the present image
# -   "   1 to skip ahead 10 images
# - press - to go to the previous image
# -   "   e to end the program

# %%
# !pip install --upgrade pip

# %%
# !pip install opencv-python

# %%
import math
def write_annot(obj_type, obj_annots_dir, obj_f_num, org_f_path,org_f_width,org_f_height,org_f_depth, refPts, upscale):
    # With credit to: 
    # https://www.geeksforgeeks.org/reading-writing-text-files-python/
    annot_file_path = obj_annots_dir+obj_f_num+'.xml'
    annot_file = open(annot_file_path,"w") 

    annot_file.write("<annotation>\n") 
    annot_file.write("	<folder>"+obj_type+"</folder>\n") 
    annot_file.write("	<filename>"+obj_f_num+".jpg</filename>\n") 
    annot_file.write("	<path>"+org_f_path+"</path>\n") 
    annot_file.write("	<source>\n") 
    annot_file.write("		<database>pompeiiinpictures.com</database>\n") 
    annot_file.write("	</source>\n") 
    annot_file.write("	<size>\n") 
    annot_file.write("		<width>"+str(org_f_width)+"</width>\n") 
    annot_file.write("		<height>"+str(org_f_height)+"</height>\n") 
    annot_file.write("		<depth>"+str(org_f_depth)+"</depth>\n") 
    annot_file.write("	</size>\n") 
    annot_file.write("	<segmented>0</segmented>\n") 
    for ocn in range(0,len(refPts)):
        refPt = refPts[ocn]
        refPtMin = refPt[0]
        refPtMax = refPt[1]
        annot_file.write("	<object>\n") 
        annot_file.write("		<name>"+obj_type+"</name>\n") 
        #annot_file.write("		<pose>Unspecified</pose>\n") 
        annot_file.write("		<truncated>0</truncated>\n") 
        annot_file.write("		<difficult>0</difficult>\n") 
        annot_file.write("		<bndbox>\n") 
        annot_file.write("			<xmin>"+str(refPtMin[0])+"</xmin>\n") 
        annot_file.write("			<ymin>"+str(refPtMin[1])+"</ymin>\n") 
        annot_file.write("			<xmax>"+str(refPtMax[0])+"</xmax>\n") 
        annot_file.write("			<ymax>"+str(refPtMax[1])+"</ymax>\n") 
        annot_file.write("		</bndbox>\n") 
        annot_file.write("		<bndbox_original>\n") 
        annot_file.write("			<xmin>"+str(math.floor(refPtMin[0]*upscale))+"</xmin>\n") 
        annot_file.write("			<ymin>"+str(math.floor(refPtMin[1]*upscale))+"</ymin>\n") 
        annot_file.write("			<xmax>"+str(math.floor(refPtMax[0]*upscale))+"</xmax>\n") 
        annot_file.write("			<ymax>"+str(math.floor(refPtMax[1]*upscale))+"</ymax>\n") 
        annot_file.write("		</bndbox_original>\n") 

        annot_file.write("	</object>\n") 
    annot_file.write("</annotation>\n") 
    annot_file.close()

# %%
# import the necessary packages

import cv2

# initialize the list of reference points

refPt = []
refPts = []

def click_and_crop(event, x, y, flags, param):
	# grab references to the global variables
	global refPt, cropping

	# if the left mouse button was clicked, record the starting
	# (x, y) coordinates and indicate that cropping is being
	# performed
	if event == cv2.EVENT_LBUTTONDOWN:
		refPt = [(x, y)]
		cropping = True

	# check to see if the left mouse button was released
	elif event == cv2.EVENT_LBUTTONUP:
		# record the ending (x, y) coordinates and indicate that
		# the cropping operation is finished
		refPt.append((x, y))
		cropping = False

		# draw a rectangle around the region of interest
		cv2.rectangle(resized, refPt[0], refPt[1], (0, 0, 255), 2)
		cv2.imshow("image", resized)
		refPts.append(refPt)

# %%
def annotate_image(original_image_path, object_type, object_annots_dir, object_images_dir, object_file_num_int):
    global image,resized,resized_original,refPts
    # With credit to:
    # Adrian Rosebrock 
    # https://www.pyimagesearch.com/2015/03/09/capturing-mouse-click-events-with-python-and-opencv/
    object_file_num_int_return = object_file_num_int
    object_file_num = "0000"+str(object_file_num_int)
    object_file_num = object_file_num[-5:]
    print("original_image_path", original_image_path)
    # load the image, clone it, and setup the mouse callback function
    refPts = []
    image = []
    image = cv2.imread(original_image_path)
    #print('Original Dimensions 2: ',image.shape)
    #plt.imshow(imgage, cmap = 'gray', interpolation = 'bicubic')
    #plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    #plt.show()

    # With credit to for image resizing
    # https://www.tutorialkart.com/opencv/python/opencv-python-resize-image/
    scale_percent = 800/image.shape[1] # percent of original size
    upscale = 1/scale_percent
    #print(scale_percent)
    width = int(image.shape[1] * scale_percent )
    height = int(image.shape[0] * scale_percent )
    dim = (width, height)
    # resize image
    resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    resized_original = resized.copy()
     
    #print('Resized Dimensions : ',resized.shape)
 
    #clone = resized.copy()
    #cv2.startWindowThread()
    #cv2.namedWindow("image")
    #cv2.setMouseCallback("image", click_and_crop)

    # keep looping until the 'c' key is pressed
    while True:
        # display the image and wait for a keypress
        cv2.imshow("image", resized)
        cv2.moveWindow("image", 0,50)
        key = cv2.waitKey(1) & 0xFF

        # if the 'c' key is pressed, break from the loop
        if key == ord("c"):
            object_file_num_int_return = object_file_num_int_return +1
            break
        if key == ord("w"):
            write_annot(object_type, object_annots_dir, object_file_num, original_image_path,resized.shape[1],resized.shape[0],resized.shape[2], refPts,upscale)
            cv2.imwrite(object_images_dir+object_file_num+".jpg",resized_original)
            cv2.imwrite(object_images_dir+"original\\"+object_file_num+".jpg",image)
            object_file_num_int_return = object_file_num_int_return +1
            break
        if key == ord("-"):
            object_file_num_int_return = object_file_num_int_return-1
            break
        if key == ord("+"):
            object_file_num_int_return = object_file_num_int_return+1
            break
        if key == ord("1"):
            object_file_num_int_return = object_file_num_int_return+10
            break
        if key == ord("9"):
            object_file_num_int_return = object_file_num_int_return+90
            break            
        if key == ord("e"):
            object_file_num_int_return = -1
            break    

    #print(refPts)

    # close all open windows
    cv2.destroyAllWindows()
    image=None

    return object_file_num_int_return 
#object_type = 'opus_incertum'
#object_annots_dir = '/home/student/data_5000_project/data/images/construction_types/processed/annots/'
#object_images_dir = '/home/student/data_5000_project/data/images/construction_types/processed/images/'
#object_file_num = '00001'
    #write_annot(object_type, object_annots_dir, object_file_num, original_file_path,resized.shape[1],resized.shape[0],resized.shape[2], refPts)
    #cv2.imwrite(object_images_dir+object_file_num+".jpg",resized_original)

# %%
# With credit to for getting just files
# https://stackoverflow.com/questions/3207219/how-do-i-list-all-files-of-a-directory
object_type = 'captain_white_diary'

raw_images_directory = 'C:\\a_orgs\\carleton\\hist3814\\R\\'+object_type+'\\'
from os import listdir
from os.path import isfile, join
raw_image_files = [f for f in listdir(raw_images_directory) if isfile(join(raw_images_directory, f))]

object_annots_dir = raw_images_directory+'processed\\annots\\'
object_images_dir = raw_images_directory+'processed\\images\\'
object_file_num_int=0
while object_file_num_int>-1:
    cv2.startWindowThread()
    #cv2_window_name = "image" + str(object_file_num_int)+" "+raw_image_files[object_file_num_int]
    cv2_window_name = "image"
    cv2.namedWindow(cv2_window_name)
    cv2.setMouseCallback(cv2_window_name, click_and_crop)
    original_image_path = raw_images_directory + raw_image_files[object_file_num_int]
    #print(original_image_path)
    #print(raw_image_files[object_file_num_int])
    object_file_num_int = annotate_image(original_image_path, object_type, object_annots_dir, object_images_dir, object_file_num_int)
    print("                                                                                                  ",object_file_num_int)
    cv2.destroyAllWindows()
# Out:
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0529.JPG
#                                                                                                    1
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0530.JPG
#                                                                                                    2
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0531.JPG
#                                                                                                    3
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0532.JPG
#                                                                                                    4
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0533.JPG
#                                                                                                    14
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0543.JPG
#                                                                                                    24
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0553.JPG
#                                                                                                    25
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0554.JPG
#                                                                                                    26
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0555.JPG
#                                                                                                    27
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0556.JPG
#                                                                                                    28
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0557.JPG
#                                                                                                    29
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0558.JPG
#                                                                                                    30
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0559.JPG
#                                                                                                    31
# original_image_path C:\a_orgs\carleton\hist3814\R\captain_white_diary\IMG_0560.JPG
#                                                                                                    -1

# %%
print(onlyfiles[0] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7680ca36294f> in <module>()
# ----> 1 print(onlyfiles[0] )
#
# NameError: name 'onlyfiles' is not defined

# %%
object_boxes_output_dir = raw_images_directory+'processed\\selected\\'

import cv2
from xml.etree import ElementTree
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(object_annots_dir) if isfile(join(object_annots_dir, f))]

for fn in onlyfiles:
    #print(fn)
    tree = ElementTree.parse(object_annots_dir+fn)
    # get the root of the document
    root = tree.getroot()
    # extract each bounding box
    
    fn_image = root.find('./filename').text
    #print(fn_image)
    box_num=0
    for box in root.findall('.//bndbox_original'):
        box_num=box_num+1
        xmin = int(box.find('xmin').text)
        ymin = int(box.find('ymin').text)
        xmax = int(box.find('xmax').text)
        ymax = int(box.find('ymax').text)
        if(ymin>ymax):
            ytemp = ymin
            ymin = ymax
            ymax=ytemp
        if(xmin>xmax):
            xtemp = xmin
            xmin = xmax
            xmax=xtemp            
        coors = [xmin, ymin, xmax, ymax]
        #print(coors)
        
        img = cv2.imread(object_images_dir+'original\\'+fn_image)
        crop_img = img[ymin:ymax, xmin:xmax]
        print(crop_img.shape)
        fntd = object_boxes_output_dir+"td_"+fn[:5]+"_b"+str(box_num)+fn_image[5:]
        print(fntd)
        cv2.imwrite(fntd,crop_img)
# Out:
# (1618, 1380, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00000_b1.jpg
# (590, 1312, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00000_b2.jpg
# (2393, 1357, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00001_b1.jpg
# (2143, 1440, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00001_b2.jpg
# (2071, 1380, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00002_b1.jpg
# (2147, 1440, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00002_b2.jpg
# (1070, 1358, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00003_b1.jpg
# (1599, 1379, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00003_b2.jpg
# (1607, 1357, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00004_b1.jpg
# (1209, 1372, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00004_b2.jpg
# (2062, 1708, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00005_b1.jpg
# (1613, 1708, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00005_b2.jpg
# (1502, 1739, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00006_b1.jpg
# (1200, 1688, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00006_b2.jpg
# (1733, 1704, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00007_b1.jpg
# (1577, 1673, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00007_b2.jpg
# (1305, 1784, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00008_b1.jpg
# (1583, 1668, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00008_b2.jpg
# (1260, 1779, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00009_b1.jpg
# (1598, 1643, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00009_b2.jpg
# (1673, 1703, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00010_b1.jpg
# (2117, 1653, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00010_b2.jpg
# (2878, 1809, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00011_b1.jpg
# (2314, 1815, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00011_b2.jpg
# (2450, 1779, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00012_b1.jpg
# (2036, 1663, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00012_b2.jpg
# (1250, 1749, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00013_b1.jpg
# (1548, 1668, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00013_b2.jpg
# (2631, 1864, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00014_b1.jpg
# (1754, 1649, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00014_b2.jpg
# (1280, 1804, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00015_b1.jpg
# (862, 1684, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00015_b2.jpg
# (1527, 1622, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00016_b1.jpg
# (1940, 1784, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00017_b1.jpg
# (1487, 1709, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00017_b2.jpg
# (1774, 1769, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00018_b1.jpg
# (1533, 1769, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00018_b2.jpg
# (1965, 1779, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00019_b1.jpg
# (1295, 1719, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00019_b2.jpg
# (2172, 1729, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00020_b1.jpg
# (2716, 1835, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00020_b2.jpg
# (2379, 1799, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00021_b1.jpg
# (1769, 1754, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00021_b2.jpg
# (2495, 1875, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00022_b1.jpg
# (1790, 1779, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00022_b2.jpg
# (2283, 1875, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00023_b1.jpg
# (1275, 1769, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00023_b2.jpg
# (1819, 1875, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00024_b1.jpg
# (2132, 1845, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00024_b2.jpg
# (1411, 1920, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00025_b1.jpg
# (1119, 1689, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00025_b2.jpg
# (2439, 1980, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00026_b1.jpg
# (882, 1784, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00026_b2.jpg
# (1562, 1905, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00027_b1.jpg
# (1633, 1764, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00027_b2.jpg
# (1291, 1830, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00030_b1.jpg
# (2263, 1739, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00030_b2.jpg
# (2082, 1935, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00031_b1.jpg
# (1880, 1945, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00032_b1.jpg
# (1356, 1764, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00032_b2.jpg
# (837, 1845, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00033_b1.jpg
# (1502, 1870, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00033_b2.jpg
# (2978, 1885, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00034_b1.jpg
# (2011, 1840, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00034_b2.jpg
# (1315, 1799, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00035_b1.jpg
# (917, 1794, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00035_b2.jpg
# (2439, 1855, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00036_b1.jpg
# (1401, 1800, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00036_b2.jpg
# (821, 1805, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00037_b1.jpg
# (645, 1759, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00037_b2.jpg
# (2052, 1920, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00038_b1.jpg
# (1260, 1814, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00038_b2.jpg
# (2011, 1850, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00039_b1.jpg
# (902, 1744, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00039_b2.jpg
# (1527, 1870, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00040_b1.jpg
# (1880, 1854, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00040_b2.jpg
# (1663, 1890, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00041_b1.jpg
# (1335, 1764, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00041_b2.jpg
# (1890, 1965, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00042_b1.jpg
# (1053, 1795, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00042_b2.jpg
# (1785, 1880, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00043_b1.jpg
# (1351, 1834, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00043_b2.jpg
# (1558, 1870, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00044_b1.jpg
# (1588, 1885, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00044_b2.jpg
# (1461, 1870, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00045_b1.jpg
# (2051, 1875, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00045_b2.jpg
# (2636, 1905, 3)
# C:\a_orgs\carleton\hist3814\R\captain_white_diary\processed\selected\td_00046_b1.jpg
